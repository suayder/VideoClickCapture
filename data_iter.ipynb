# %%
from sideseeing_tools import sideseeing

# %%
ds = sideseeing.SideSeeingDS(root_dir='/data/side_seing/sideseeing-hospitals')
# Out:
# WARNING. /data/side_seing/sideseeing-hospitals/./metadata.csv has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_HM_R02.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_CHE_R01.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/JUNDIAI_HSV_R01.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_HM_R04.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_CHE_R04.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/JUNDIAI_HSV_B01.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_CHE_R05.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/JUNDIAI_HSV_R02.png has been ignored.
# WARNING. /data/side_seing/sideseeing-hospitals/./routes/SANTOS_CHE_B01.png has been ignored.
# ...

# %%
ds.instance['data#Jundiai_HSV#Block01-2024-02-28-15-06-34-538']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ds.instance['data#Jundiai_HSV#Block01-2024-02-28-15-06-34-538']
#
# AttributeError: 'SideSeeingDS' object has no attribute 'instance'
